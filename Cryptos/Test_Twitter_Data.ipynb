# %% [markdown]
# #### Mostrar el funcionamiento de data_twitter.py

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from download import data_twitter
con = data_twitter.data_twitter()

params = {
    "screen_name": 'elonmusk',
    #"crypto_tweet": ['Epic']
         }

tweets = con.twitter_download(params)

df_1 = pd.DataFrame()
for t in tweets:
    df = pd.DataFrame.from_dict(t._json, orient='index').transpose()
    df_1 = pd.concat([df_1,df])
    #Filtrado por palabra
    #for c in params['crypto_tweet']:
    #    if c.upper() in df['full_text'][0].upper():
    #        df_1 = pd.concat([df_1,df])
df_1['created_at'] = pd.to_datetime(df_1['created_at']).dt.strftime('%Y-%m-%d %H:%M:%S')
df_1['created_at'] = pd.to_datetime(df_1['created_at'])
df_1.head()
# Out:
#            created_at                   id               id_str  \
# 0 2021-07-02 13:20:14  1410951450604175366  1410951450604175366
# 0 2021-07-02 13:12:57  1410949616992882695  1410949616992882695
# 0 2021-07-02 13:09:28  1410948739145994244  1410948739145994244
# 0 2021-07-02 13:05:19  1410947694802006019  1410947694802006019
# 0 2021-07-02 12:54:59  1410945093981282306  1410945093981282306
#
#                                            full_text truncated  \
# 0                            https://t.co/oGKHhHROQa     False
# 0  @PPathole @CarlosV_Resiste @pcgamer Yeah, main...     False
# 0  Congrats Tesla Team on over 200,000 car built ...     False
# 0  @CarlosV_Resiste @pcgamer These days, I mostly...     False
# 0                    @pcgamer Dead Space 2 was great     False
#
#   display_text_range                                           entities  \
# 0             [0, 0]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 0          [36, 175]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 0            [0, 94]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 0          [26, 102]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 0            [9, 31]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1410951448280530952, 'id_str...
# 0                                                NaN
# 0                                                NaN
# 0  {'media': [{'id': 1410947688829308933, 'id_str...
# 0                                                NaN
#
#                                               source in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                  None
# 0  <a href="http://twitter.com/download/iphone" r...   1410948263738429441
# 0  <a href="http://twitter.com/download/iphone" r...                  None
# 0  <a href="http://twitter.com/download/iphone" r...   1410945346683949056
# 0  <a href="http://twitter.com/download/iphone" r...   1410708215529148417
#
#   in_reply_to_status_id_str in_reply_to_user_id in_reply_to_user_id_str  \
# 0                      None                None                    None
# 0       1410948263738429441          1291945442              1291945442
# 0                      None                None                    None
# 0       1410945346683949056          2434615266              2434615266
# 0       1410708215529148417            16736535                16736535
#
#   in_reply_to_screen_name                                               user  \
# 0                    None  {'id': 44196397, 'id_str': '44196397', 'name':...
# 0                PPathole  {'id': 44196397, 'id_str': '44196397', 'name':...
# 0                    None  {'id': 44196397, 'id_str': '44196397', 'name':...
# 0         CarlosV_Resiste  {'id': 44196397, 'id_str': '44196397', 'name':...
# 0                 pcgamer  {'id': 44196397, 'id_str': '44196397', 'name':...
#
#     geo coordinates place contributors is_quote_status retweet_count  \
# 0  None        None  None         None           False          8463
# 0  None        None  None         None           False            97
# 0  None        None  None         None           False          4666
# 0  None        None  None         None           False            61
# 0  None        None  None         None           False           299
#
#   favorite_count favorited retweeted possibly_sensitive lang retweeted_status  \
# 0          68853     False     False              False  und              NaN
# 0           1428     False     False                NaN   en              NaN
# 0          63710     False     False                NaN   en              NaN
# 0            881     False     False              False   en              NaN
# 0           6256     False     False                NaN   en              NaN
#
#   quoted_status_id quoted_status_id_str quoted_status_permalink quoted_status
# 0              NaN                  NaN                     NaN           NaN
# 0              NaN                  NaN                     NaN           NaN
# 0              NaN                  NaN                     NaN           NaN
# 0              NaN                  NaN                     NaN           NaN
# 0              NaN                  NaN                     NaN           NaN
